# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaunZhxiong/musa-611-midterm/blob/main/DogNYC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# dogNYC

# %%
% pip install geopandas &> /dev/null
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd

# %%
dogRun = gpd.read_file("/content/NYC Parks Dog Runs.geojson")
dogRun
# Out:
#    zipcode                                 name              system  surface  \
# 0    10038            Fishbridge Garden Dog Run    M291-DOGAREA0043     None
# 1    11360              Little Bay Park Dog Run   Q010A-DOGAREA0003     None
# 2    10471                 Canine Court Dog Run    X092-DOGAREA0018     None
# 3    10009         Tompkins Square Park Dog Run    M088-DOGAREA0026     None
# 4    11228             Dyker Beach Park Dog Run    B028-DOGAREA0007     None
# ..     ...                                  ...                 ...      ...
# 82   11101     Hunters Point South Park Dog Run    Q471-DOGAREA0017     None
# 83    None  Overlook Dog Park / The Barking Lot    Q083-DOGAREA0009  Natural
# 84   11423              Cunningham Park Dog Run    Q021-DOGAREA0007     None
# 85   10454              St. Mary's Park Dog Run    X045-DOGAREA0014  Natural
# 86   10065         Andrew Haswell Green Dog Run  M108Q1-DOGAREA0036     None
#
# ...

# %% [markdown]
# use the techniques in Yelp review

# %%
episodeSummaryNotName = episodeSummary
episodeSummaryNotName["Summary"] = episodeSummaryNotName["Summary"].str.findall( r'\w+|^\s\w+')

# %%
ignored = ["Rachel","Ross","Monica","Chandler","Joey","Phoebe","Gunther",
       "Gunther","Janice","Carol","Judy","Jack","Susan","Marcel","Barry",
       "Mr. Heckles","Paolo","Ben","Estelle","Julie","Mindy","Bobby",
       "Terry","Mr. Douglas","Jasmine","Kiki","Michele","Nora","David","Steve","Frank",
       "Richard","Mr. Treeger","Sandra","Eddie","Dr. Mike Horton","Joanna","Dr. Leonard Green",
       "Sophie","Bonnie","Mark","Pete","Kate","Marshall","Lauren","Mr. Kaplan Jr.","Chloe",
       "Isaac","Alice","Phoebe","Doug","Ugly Naked Guy","Dina","Emily","Kathy","Joshua",
       "Mr. Waltham","Stephen","Andrea","Gary","Danny","Dr. Ledbetter","Randall","Kim",
       "Helena","Mr. Zelner","Janine","Jill","Elizabeth","Paul",'Russell',"Dr. Roger","Jake",
       "Richard",'Mona',"Dr. Long","Eric",'Parker',"Emma",'Mike',"Charlie",'Gavin',
       'Steve',"Molly","Claudia",'Ken',"Amy" ,'Clifford','Bitsy','Theodore',"Erica"]

# %%
for i in range(len(episodeSummaryNotName)):
  print(f"Is processing episode: {i}") if i % 40 == 0 else 0
  for j in range(len(episodeSummaryNotName["Summary"][i])):
    episodeSummaryNotName["Summary"][i][j] = episodeSummaryNotName["Summary"][i][j] if episodeSummaryNotName["Summary"][i][j] not in ignored else " "
# Out:
# Is processing episode: 0
# Is processing episode: 40
# Is processing episode: 80
# Is processing episode: 120
# Is processing episode: 160
# Is processing episode: 200

# %%
episodeSummaryNotName.head(n=6)
# Out:
#    Year_of_prod  Season                                   Episode_Title  \
# 0          1994       1            The One with the Sonogram at the End
# 1          1994       1                          The One with the Thumb
# 2          1994       1              The One with George Stephanopoulos
# 3          1994       1  The One with the East German Laundry Detergent
# 4          1994       1                           The One with the Butt
# 5          1994       1                       The One with the Blackout
#
#    Duration                                            Summary  \
# 0        22  [ , finds, out, his, ex, wife, is, pregnant,  ...
# 1        22  [ , becomes, irritated, when, everyone, likes,...
# 2        22  [ , and,  , take,  , to, a, hockey, game, to, ...
# 3        22  [Eager, to, spend, time, with,  ,  , pretends,...
# 4        22  [ , s, obsessiveness, is, put, to, the, test, ...
# 5        22  [When, New, York, suffers, from, a, blackout, ...
#
# ...

# %%
collapsedText = np.array(episodeSummaryNotName['Summary'])

# %%
AllLocations = []
for i in range(len(collapsedText)):
  temp = ' '.join(collapsedText[i])
  cities = GeoText(temp).cities
  AllLocations.append(cities)

# %%
AllLocations
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  ['York'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Los Angeles'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['London'],
#  ['London'],
#  [],
#  [],
#  [],
#  [],
#  ['London'],
#  ['London'],
#  [],
#  ['London'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Las Vegas'],
#  ['Las Vegas'],
#  [],
#  ['New York'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
# ...
